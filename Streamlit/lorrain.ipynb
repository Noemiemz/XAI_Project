# %%
import tensorflow as tf

model_path = "C:\\Users\\lorra\\OneDrive - De Vinci\\A5\\explanibility AI\\XAI_Project\\Streamlit\\saved_model\\model"

model = tf.saved_model.load(model_path)
# model = tf.keras.models.load_model(model_path)
model.save('model.h5', save_format='h5')
# Out:
# WARNING:tensorflow:From C:\Users\lorra\AppData\Roaming\Python\Python310\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 7
#       5 model = tf.saved_model.load(model_path)
#       6 # model = tf.keras.models.load_model(model_path)
# ----> 7 model.save('model.h5', save_format='h5')
#
# AttributeError: '_UserObject' object has no attribute 'save'
